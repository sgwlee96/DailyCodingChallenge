# %%
# p.2447 별 찍기 - 10

def recurs(n):
    print("*"*n)
    recurs(n-1)

    if n == 0:
        return 0


print(recurs(3))
# Out:
# ***
# **
# *
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# <ipython-input-5-bbfa7df632fb> in <module>
#       9
#      10
# ---> 11 print(recurs(3))
#
# <ipython-input-5-bbfa7df632fb> in recurs(n)
#       3 def recurs(n):
#       4     print("*"*n)
# ----> 5     recurs(n-1)
#       6
#       7     if n == 0:
#
# ... last 1 frames repeated, from the frame below ...
#
# <ipython-input-5-bbfa7df632fb> in recurs(n)
#       3 def recurs(n):
#       4     print("*"*n)
# ----> 5     recurs(n-1)
#       6
#       7     if n == 0:
#
# RecursionError: maximum recursion depth exceeded while calling a Python object
